# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('Directory.csv')
df
# Out:
#                 Name  EmployeeNumber     PhoneNumber  \
# 0      Jennifer Boyd               1  (578)-285-8371
# 1      Heather Smith               2  (571)-982-0381
# 2        Beth Walker               4  (022)-091-9120
# 3      Kelly Padilla               5  (132)-530-4546
# 4        Angel Moore               7  (411)-108-8099
# ...              ...             ...             ...
# 1465  David Gonzalez            2061  (285)-108-6327
# 1466  Kimberly Kelly            2062  (406)-242-6488
# 1467       Cory Pugh            2064  (795)-737-5063
# 1468      Autumn Roy            2065  (474)-301-8082
# 1469     Carol Clark            2068  (958)-931-1773
#
#                         JobRole WorkLocation  Salary         Username  \
# 0               Sales Executive           MN   71916         JenBoyd1
# 1            Research Scientist           MD   61560        HeaSmith2
# 2         Laboratory Technician           CT   25080       BetWalker4
# ...

# %%
X = df[['JobRole', 'WorkLocation']]
y = df['Salary']
# X_numeric = pd.get_dummies(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# model = LinearRegression()
# model.fit(X_numeric,y)
# y_pred = model.predict(X_test)

# %%
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

preprocessor = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), ['JobRole', 'WorkLocation'])])
pipeline = Pipeline(steps=[('preprocessor', preprocessor), ('regressor', LinearRegression())])

pipeline.fit(X_train, y_train)
y_pred = pipeline.predict(X_test)

distinct_combinations = np.unique(y_pred)
print("Predicted salary: ")
# for i in range(len(y_test)):
#     print(f"Job Role:{X_test.iloc[i]['JobRole']}, Work Location: {X_test.iloc[i]['WorkLocation']}, Predicted Salary: {y_pred[i]:.2f}")
# for salary in distinct_combinations:
#     print(f"Job Role:{X_test.iloc[i]['JobRole']}, Work Location: {X_test.iloc[i]['WorkLocation']}, Predicted Salary: {salary:.2f}")
# Out:
# Predicted salary:
# Job Role:Manufacturing Director, Work Location: MN, Predicted Salary: 29006.07
# Job Role:Manufacturing Director, Work Location: MN, Predicted Salary: 30239.31
# Job Role:Manufacturing Director, Work Location: MN, Predicted Salary: 30703.62
# Job Role:Manufacturing Director, Work Location: MN, Predicted Salary: 31002.56
# Job Role:Manufacturing Director, Work Location: MN, Predicted Salary: 32473.66
# Job Role:Manufacturing Director, Work Location: MN, Predicted Salary: 36839.94
# Job Role:Manufacturing Director, Work Location: MN, Predicted Salary: 37214.53
# Job Role:Manufacturing Director, Work Location: MN, Predicted Salary: 38073.18
# Job Role:Manufacturing Director, Work Location: MN, Predicted Salary: 38447.77
# Job Role:Manufacturing Director, Work Location: MN, Predicted Salary: 38537.49
# Job Role:Manufacturing Director, Work Location: MN, Predicted Salary: 38836.43
# Job Role:Manufacturing Director, Work Location: MN, Predicted Salary: 38912.08
# ...

# %%
plt.figure(figsize=(30, 20))
plt.plot(range(len(y_test)), y_test, marker = 'o', label = 'Actual Salary')
plt.plot(range(len(y_test)), y_pred, marker = 'o', label = 'Predicted Salary', color='tab:orange', alpha=0.5)
plt.xlabel('Data Point')
plt.ylabel('Salary')
plt.title('Actual vs. Predicted Salary')
plt.legend()
plt.show()
